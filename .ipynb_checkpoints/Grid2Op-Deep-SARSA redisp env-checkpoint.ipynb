# %% [markdown]
# # Grid2Op with Deep SARSA

# %% [markdown]
# ## Import the necessary software libraries:

# %%
import grid2op
import random
import copy
import gym
import numpy as np
import torch
import torch.nn.functional as F

import matplotlib.pyplot as plt

from typing import Callable
from torch import nn as nn
from torch.optim import AdamW
from tqdm import tqdm

from grid2op.gym_compat import GymEnv, BoxGymObsSpace, DiscreteActSpace
from gym import Env
from gym.utils.env_checker import check_env
try:
    from lightsim2grid import LightSimBackend
    bk_cls = LightSimBackend
except ImportError as exc:
    print(f"Error: {exc} when importing faster LightSimBackend")
    from grid2op.Backend import PandaPowerBackend
    bk_cls = PandaPowerBackend
    
from utils import plot_cost_to_go, plot_max_q, test_agent, plot_stats, seed_everything    
# %matplotlib notebook

# %% [markdown]
# ## Create and prepare the environment

# %% [markdown]
# ### Create the environment & Convert into Gym Compatible

# %%
env_name = "rte_case14_redisp"
#env = grid2op.make(env_name, test=True, backend=bk_cls()
env = grid2op.make(env_name)
print(type(env))
gym_env = GymEnv(env)


gym_env.observation_space = BoxGymObsSpace(env.observation_space)
gym_env.action_space = DiscreteActSpace(env.action_space)

#print(f"Is gym_env and open AI gym environment: {isinstance(gym_env, gym.Env)}")
# Out:
# <class 'abc.Environment_rte_case14_redisp'>
# e:\masters\sem 2\analytics project\code\grid2op\grid2op\gym_compat\discrete_gym_actspace.py:171: UserWarning: The class "DiscreteActSpace" should mainly be used to consider only discrete actions (eg. set_line_status, set_bus or change_bus). Though it is possible to use "redispatch" when building it, be aware that this continuous action will be treated as discrete by splitting it into bins. Consider using the "BoxGymActSpace" for these attributes.
#   warnings.warn(

# %%
state_dims = gym_env.observation_space.shape[0]
num_actions = gym_env.action_space.n

# %%
num_actions
# Out:
# 463

# %% [markdown]
# ### Prepare the environment to work with PyTorch

# %%
class PreprocessEnv(gym.Wrapper):
    
    def __init__(self, env):
        gym.Wrapper.__init__(self, env)
    
    def reset(self):
        obs = self.env.reset()
        print(f'type={ type(obs) }')
        return torch.from_numpy(obs).unsqueeze(dim=0).float()
    
    def step(self, action):
        action = action.item()
        next_state, reward, done, info = self.env.step(action)
        next_state = torch.from_numpy(next_state).unsqueeze(dim=0).float()
        reward = torch.tensor(reward).view(1, -1).float()
        done = torch.tensor(done).view(1, -1)
        return next_state, reward, done, info

# %%
env = PreprocessEnv(gym_env)

# %%
state = env.reset()
action = torch.tensor(0)
next_state, reward, done, _ = env.step(action)
# Out:
# type=<class 'numpy.ndarray'>

# %% [markdown]
# ### Create the Q-Network: $\hat q(s,a| \theta)$

# %%
q_network = nn.Sequential(
    nn.Linear(state_dims, 550),
    nn.ReLU(),
    nn.Linear(550, 500),
    nn.ReLU(),
    nn.Linear(500, num_actions))

# %%
q_network
# Out:
# Sequential(
#   (0): Linear(in_features=453, out_features=550, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=550, out_features=500, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=500, out_features=463, bias=True)
# )

# %% [markdown]
# ### Create the target Q-Network: $\hat q(s, a|\theta_{targ})$

# %%
target_q_network = copy.deepcopy(q_network).eval()

# %% [markdown]
# ### Create the $\epsilon$-greedy policy: $\pi(s)$

# %%
def policy(state, epsilon=0.05):
    if torch.rand(1) < epsilon:
        return torch.randint(num_actions, (1, 1))
    else:
        av = q_network(state).detach()
        return torch.argmax(av, dim=-1, keepdim=True)

# %% [markdown]
# ### Plot the cost to go: $ - \max_a \hat q(s,a|\theta)$

# %%
#plot_cost_to_go(gym_env, q_network, xlabel='Car Position', ylabel='Velocity')

# %%
class ReplayMemory:

    def __init__(self, capacity=1000000):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def insert(self, transition):
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = transition
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        assert self.can_sample(batch_size)

        batch = random.sample(self.memory, batch_size)
        batch = zip(*batch)
        return [torch.cat(items) for items in batch]

    def can_sample(self, batch_size):
        print(f'can_sample_self.memory = {len(self.memory)}')
        return len(self.memory) >= batch_size * 10

    def __len__(self):
        return len(self.memory)

# %% [markdown]
# # Deep SARSA Algorithm

# %% [markdown]
# ![Screenshot%202021-03-11%20at%2019.03.36.png](attachment:Screenshot%202021-03-11%20at%2019.03.36.png)

# %%
def deep_sarsa(q_network, policy, episodes, alpha=0.001, batch_size=32, gamma=0.99, epsilon=0.):
    print(f'<<< deep_sarsa >>>')
    optim = AdamW(q_network.parameters(), lr=alpha) #optimiser to optimise weight calculation of neural networks
    memory = ReplayMemory() #Initialising memory to store State, Action, Reward, and Next State
    stats = {'MSE Loss': [], 'Returns': []} #Dict to store statistics
    
    for episode in tqdm(range(1, episodes + 1)):
        print(f'<<< episode >>>')
        state = env.reset() #getting initial state
        done = False
        ep_return = 0
        while not done:
            print(f'<<< while >>>')
            action = policy(state, epsilon) #Getting first action greedily with randomisation factor Epsilon
            next_state, reward, done, _ = env.step(action) #taking selected action on environment
            memory.insert([state, action, reward, done, next_state]) #Storing the results to memory
            print(f'batch_size = {memory.can_sample(batch_size)}') #printing the size of the memory
            if memory.can_sample(batch_size): #samples will be created only if memory pool is 10 times of batch size
                print(f'<<< if memory >>>')
                state_b, action_b, reward_b, done_b, next_state_b = memory.sample(batch_size) #creating batches to train neural network
                qsa_b = q_network(state_b).gather(1, action_b) #providing the state to neural network and comparing the 
                                                            #actions with actions stored in memory and gather the experiences
                next_action_b = policy(next_state_b) #using greedy epsilon policy to greedily get next actions
                next_qsa_b = target_q_network(next_state_b).gather(1, next_action_b) #provide next state and next action to a target neural network
                                                                                    #and gather its experiences
                target_b = reward_b + ~done_b * gamma * next_qsa_b #discount the experiences of target network
                loss = F.mse_loss(qsa_b, target_b) #find a Mean square error loss
                print(f'qsa_b = {qsa_b}, target_b = {target_b}')
                q_network.zero_grad() #reset the gradients of the network
                loss.backward() #calculate gradients using backward propogation
                optim.step() # Iterate over all parameters (tensors) that are supposed 
                            # to be updated and use internally stored grad to update their values
                
                loss.item() # get the loss
                print(loss.item())
                stats['MSE Loss'].append(loss.item())
            
            state = next_state
            ep_return += reward.item()
        
        stats['Returns'].append(ep_return)
        
        if episode % 10 == 0:
            target_q_network.load_state_dict(q_network.state_dict()) #After every 10 episodes load state of original network to
                                                                    # target network
        
    return stats

# %%
print(q_network)
# Out:
# Sequential(
#   (0): Linear(in_features=453, out_features=550, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=550, out_features=500, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=500, out_features=463, bias=True)
# )

# %%
stats = deep_sarsa(q_network, policy, 200, alpha=0.001, epsilon=0.05)
# Out:
#   0%|                                                                                          | 0/200 [00:00<?, ?it/s]
# <<< deep_sarsa >>>
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 1
# can_sample_self.memory = 2
# can_sample_self.memory = 3
# can_sample_self.memory = 4
# can_sample_self.memory = 5
# can_sample_self.memory = 6
# can_sample_self.memory = 7
# can_sample_self.memory = 8
# can_sample_self.memory = 9
# can_sample_self.memory = 10
# can_sample_self.memory = 11
# can_sample_self.memory = 12
# can_sample_self.memory = 13
# can_sample_self.memory = 14
# can_sample_self.memory = 15
# can_sample_self.memory = 16
# can_sample_self.memory = 17
# can_sample_self.memory = 18
# can_sample_self.memory = 19
# can_sample_self.memory = 20
# can_sample_self.memory = 21
# can_sample_self.memory = 22
# can_sample_self.memory = 23
# can_sample_self.memory = 24
# can_sample_self.memory = 25
# can_sample_self.memory = 26
# can_sample_self.memory = 27
# can_sample_self.memory = 28
# can_sample_self.memory = 29
# can_sample_self.memory = 30
# can_sample_self.memory = 31
# can_sample_self.memory = 32
# can_sample_self.memory = 33
# can_sample_self.memory = 34
# can_sample_self.memory = 35
#   0%|▍                                                                                 | 1/200 [00:01<04:03,  1.23s/it]
# can_sample_self.memory = 36
# can_sample_self.memory = 37
# can_sample_self.memory = 38
# can_sample_self.memory = 39
# can_sample_self.memory = 40
# can_sample_self.memory = 41
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 42
# can_sample_self.memory = 43
# can_sample_self.memory = 44
# can_sample_self.memory = 45
# can_sample_self.memory = 46
# can_sample_self.memory = 47
# can_sample_self.memory = 48
# can_sample_self.memory = 49
# can_sample_self.memory = 50
# can_sample_self.memory = 51
# can_sample_self.memory = 52
# can_sample_self.memory = 53
# can_sample_self.memory = 54
# can_sample_self.memory = 55
# can_sample_self.memory = 56
# can_sample_self.memory = 57
# can_sample_self.memory = 58
# can_sample_self.memory = 59
# can_sample_self.memory = 60
# can_sample_self.memory = 61
# can_sample_self.memory = 62
# can_sample_self.memory = 63
# can_sample_self.memory = 64
# can_sample_self.memory = 65
# can_sample_self.memory = 66
# can_sample_self.memory = 67
# can_sample_self.memory = 68
# can_sample_self.memory = 69
# can_sample_self.memory = 70
# can_sample_self.memory = 71
# can_sample_self.memory = 72
# can_sample_self.memory = 73
# can_sample_self.memory = 74
# can_sample_self.memory = 75
# can_sample_self.memory = 76
# can_sample_self.memory = 77
# can_sample_self.memory = 78
# can_sample_self.memory = 79
# can_sample_self.memory = 80
# can_sample_self.memory = 81
# can_sample_self.memory = 82
# can_sample_self.memory = 83
# can_sample_self.memory = 84
# can_sample_self.memory = 85
# can_sample_self.memory = 86
# can_sample_self.memory = 87
# can_sample_self.memory = 88
# can_sample_self.memory = 89
# can_sample_self.memory = 90
# can_sample_self.memory = 91
# can_sample_self.memory = 92
# can_sample_self.memory = 93
# can_sample_self.memory = 94
# can_sample_self.memory = 95
# can_sample_self.memory = 96
# can_sample_self.memory = 97
# can_sample_self.memory = 98
# can_sample_self.memory = 99
# can_sample_self.memory = 100
# can_sample_self.memory = 101
# can_sample_self.memory = 102
# can_sample_self.memory = 103
# can_sample_self.memory = 104
# can_sample_self.memory = 105
# can_sample_self.memory = 106
# can_sample_self.memory = 107
# can_sample_self.memory = 108
# can_sample_self.memory = 109
# can_sample_self.memory = 110
# can_sample_self.memory = 111
# can_sample_self.memory = 112
# can_sample_self.memory = 113
# can_sample_self.memory = 114
# can_sample_self.memory = 115
# can_sample_self.memory = 116
# can_sample_self.memory = 117
# can_sample_self.memory = 118
# can_sample_self.memory = 119
#   1%|▊                                                                                 | 2/200 [00:03<06:00,  1.82s/it]
# can_sample_self.memory = 120
# can_sample_self.memory = 121
# can_sample_self.memory = 122
# can_sample_self.memory = 123
# can_sample_self.memory = 124
# can_sample_self.memory = 125
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 126
# can_sample_self.memory = 127
# can_sample_self.memory = 128
# can_sample_self.memory = 129
# can_sample_self.memory = 130
# can_sample_self.memory = 131
# can_sample_self.memory = 132
# can_sample_self.memory = 133
# can_sample_self.memory = 134
# can_sample_self.memory = 135
# can_sample_self.memory = 136
# can_sample_self.memory = 137
# can_sample_self.memory = 138
# can_sample_self.memory = 139
# can_sample_self.memory = 140
# can_sample_self.memory = 141
# can_sample_self.memory = 142
# can_sample_self.memory = 143
# can_sample_self.memory = 144
# can_sample_self.memory = 145
# can_sample_self.memory = 146
# can_sample_self.memory = 147
# can_sample_self.memory = 148
# can_sample_self.memory = 149
# can_sample_self.memory = 150
# can_sample_self.memory = 151
#   2%|█▏                                                                                | 3/200 [00:04<04:43,  1.44s/it]
# can_sample_self.memory = 152
# can_sample_self.memory = 153
# can_sample_self.memory = 154
# can_sample_self.memory = 155
# can_sample_self.memory = 156
# can_sample_self.memory = 157
# can_sample_self.memory = 158
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 159
# can_sample_self.memory = 160
# can_sample_self.memory = 161
# can_sample_self.memory = 162
# can_sample_self.memory = 163
# can_sample_self.memory = 164
# can_sample_self.memory = 165
# can_sample_self.memory = 166
# can_sample_self.memory = 167
# can_sample_self.memory = 168
# can_sample_self.memory = 169
# can_sample_self.memory = 170
# can_sample_self.memory = 171
# can_sample_self.memory = 172
# can_sample_self.memory = 173
# can_sample_self.memory = 174
# can_sample_self.memory = 175
#   2%|█▋                                                                                | 4/200 [00:05<03:38,  1.12s/it]
# can_sample_self.memory = 176
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 177
# can_sample_self.memory = 178
# can_sample_self.memory = 179
# can_sample_self.memory = 180
# can_sample_self.memory = 181
# can_sample_self.memory = 182
# can_sample_self.memory = 183
# can_sample_self.memory = 184
# can_sample_self.memory = 185
# can_sample_self.memory = 186
#   2%|██                                                                                | 5/200 [00:05<02:49,  1.15it/s]
# can_sample_self.memory = 187
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 188
# can_sample_self.memory = 189
# can_sample_self.memory = 190
# can_sample_self.memory = 191
# can_sample_self.memory = 192
# can_sample_self.memory = 193
# can_sample_self.memory = 194
# can_sample_self.memory = 195
# can_sample_self.memory = 196
# can_sample_self.memory = 197
# can_sample_self.memory = 198
# can_sample_self.memory = 199
# can_sample_self.memory = 200
# can_sample_self.memory = 201
# can_sample_self.memory = 202
# can_sample_self.memory = 203
# can_sample_self.memory = 204
# can_sample_self.memory = 205
# can_sample_self.memory = 206
#   3%|██▍                                                                               | 6/200 [00:06<02:45,  1.17it/s]
# can_sample_self.memory = 207
# can_sample_self.memory = 208
# can_sample_self.memory = 209
# can_sample_self.memory = 210
# can_sample_self.memory = 211
# can_sample_self.memory = 212
# can_sample_self.memory = 213
# can_sample_self.memory = 214
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 215
# can_sample_self.memory = 216
# can_sample_self.memory = 217
# can_sample_self.memory = 218
# can_sample_self.memory = 219
# can_sample_self.memory = 220
# can_sample_self.memory = 221
# can_sample_self.memory = 222
# can_sample_self.memory = 223
# can_sample_self.memory = 224
# can_sample_self.memory = 225
# can_sample_self.memory = 226
# can_sample_self.memory = 227
# can_sample_self.memory = 228
# can_sample_self.memory = 229
# can_sample_self.memory = 230
# can_sample_self.memory = 231
# can_sample_self.memory = 232
# can_sample_self.memory = 233
# can_sample_self.memory = 234
# can_sample_self.memory = 235
# can_sample_self.memory = 236
# can_sample_self.memory = 237
# can_sample_self.memory = 238
# can_sample_self.memory = 239
# can_sample_self.memory = 240
# can_sample_self.memory = 241
# can_sample_self.memory = 242
# can_sample_self.memory = 243
# can_sample_self.memory = 244
# can_sample_self.memory = 245
# can_sample_self.memory = 246
# can_sample_self.memory = 247
# can_sample_self.memory = 248
# can_sample_self.memory = 249
# can_sample_self.memory = 250
# can_sample_self.memory = 251
# can_sample_self.memory = 252
# can_sample_self.memory = 253
# can_sample_self.memory = 254
# can_sample_self.memory = 255
# can_sample_self.memory = 256
# can_sample_self.memory = 257
# can_sample_self.memory = 258
# can_sample_self.memory = 259
# can_sample_self.memory = 260
# can_sample_self.memory = 261
# can_sample_self.memory = 262
# can_sample_self.memory = 263
# can_sample_self.memory = 264
# can_sample_self.memory = 265
# can_sample_self.memory = 266
# can_sample_self.memory = 267
# can_sample_self.memory = 268
# can_sample_self.memory = 269
# can_sample_self.memory = 270
# can_sample_self.memory = 271
# can_sample_self.memory = 272
# can_sample_self.memory = 273
# can_sample_self.memory = 274
# can_sample_self.memory = 275
# can_sample_self.memory = 276
# can_sample_self.memory = 277
# can_sample_self.memory = 278
# can_sample_self.memory = 279
# can_sample_self.memory = 280
# can_sample_self.memory = 281
# can_sample_self.memory = 282
# can_sample_self.memory = 283
# can_sample_self.memory = 284
# can_sample_self.memory = 285
# can_sample_self.memory = 286
# can_sample_self.memory = 287
# can_sample_self.memory = 288
# can_sample_self.memory = 289
# can_sample_self.memory = 290
# can_sample_self.memory = 291
# can_sample_self.memory = 292
# can_sample_self.memory = 293
# can_sample_self.memory = 294
# can_sample_self.memory = 295
# can_sample_self.memory = 296
# can_sample_self.memory = 297
# can_sample_self.memory = 298
# can_sample_self.memory = 299
# can_sample_self.memory = 300
# can_sample_self.memory = 301
# can_sample_self.memory = 302
# can_sample_self.memory = 303
# can_sample_self.memory = 304
# can_sample_self.memory = 305
# can_sample_self.memory = 306
# can_sample_self.memory = 307
# can_sample_self.memory = 308
# can_sample_self.memory = 309
# can_sample_self.memory = 310
# can_sample_self.memory = 311
# can_sample_self.memory = 312
#   4%|██▊                                                                               | 7/200 [00:08<04:33,  1.42s/it]
# can_sample_self.memory = 313
# can_sample_self.memory = 314
# can_sample_self.memory = 315
# <<< episode >>>
# type=<class 'numpy.ndarray'>
#   4%|███▎                                                                              | 8/200 [00:09<03:27,  1.08s/it]
# can_sample_self.memory = 316
# can_sample_self.memory = 317
# can_sample_self.memory = 318
# can_sample_self.memory = 319
# can_sample_self.memory = 320
# can_sample_self.memory = 320
# 2375844.75
# can_sample_self.memory = 321
# can_sample_self.memory = 321
# 5088436.5
# can_sample_self.memory = 322
# can_sample_self.memory = 322
# 148934096.0
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 323
# can_sample_self.memory = 323
# 6128829.0
# can_sample_self.memory = 324
# can_sample_self.memory = 324
# 66793812.0
# can_sample_self.memory = 325
# can_sample_self.memory = 325
# 86714056.0
# can_sample_self.memory = 326
# can_sample_self.memory = 326
# 34752756.0
# can_sample_self.memory = 327
# can_sample_self.memory = 327
# 122371416.0
# can_sample_self.memory = 328
# can_sample_self.memory = 328
#   4%|███▋                                                                              | 9/200 [00:09<02:44,  1.16it/s]
# 17602574.0
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 329
# can_sample_self.memory = 329
#   5%|████                                                                             | 10/200 [00:09<02:05,  1.52it/s]
# 45964020.0
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 330
# can_sample_self.memory = 330
#   6%|████▍                                                                            | 11/200 [00:10<01:37,  1.93it/s]
# 40935384.0
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 331
# can_sample_self.memory = 331
# 30054684.0
# can_sample_self.memory = 332
# can_sample_self.memory = 332
# 16265722.0
# can_sample_self.memory = 333
# can_sample_self.memory = 333
# 4496816.5
# can_sample_self.memory = 334
# can_sample_self.memory = 334
# 698920.75
# can_sample_self.memory = 335
# can_sample_self.memory = 335
#   6%|████▊                                                                            | 12/200 [00:10<01:29,  2.09it/s]
# 5575220.0
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 336
# can_sample_self.memory = 336
# 43543744.0
# can_sample_self.memory = 337
# can_sample_self.memory = 337
# 36385980.0
# can_sample_self.memory = 338
# can_sample_self.memory = 338
# 14978548.0
# can_sample_self.memory = 339
# can_sample_self.memory = 339
# 3181392.25
# can_sample_self.memory = 340
# can_sample_self.memory = 340
# 7803361.5
# can_sample_self.memory = 341
# can_sample_self.memory = 341
# 11161882.0
# can_sample_self.memory = 342
# can_sample_self.memory = 342
# 11837208.0
# can_sample_self.memory = 343
# can_sample_self.memory = 343
# 10103793.0
# can_sample_self.memory = 344
# can_sample_self.memory = 344
# 7649597.5
# can_sample_self.memory = 345
# can_sample_self.memory = 345
# 3984485.0
# can_sample_self.memory = 346
# can_sample_self.memory = 346
# 2891495.75
# can_sample_self.memory = 347
# can_sample_self.memory = 347
# 3287455.75
# can_sample_self.memory = 348
# can_sample_self.memory = 348
# 4108750.5
# can_sample_self.memory = 349
# can_sample_self.memory = 349
# 1361164.75
# can_sample_self.memory = 350
# can_sample_self.memory = 350
# 572897.9375
# can_sample_self.memory = 351
# can_sample_self.memory = 351
# 276383.90625
# can_sample_self.memory = 352
# can_sample_self.memory = 352
# 342138.84375
# can_sample_self.memory = 353
# can_sample_self.memory = 353
# 89853.2578125
# can_sample_self.memory = 354
# can_sample_self.memory = 354
# 178701.875
# can_sample_self.memory = 355
# can_sample_self.memory = 355
# 5055975.0
# can_sample_self.memory = 356
# can_sample_self.memory = 356
# 6063861.0
# can_sample_self.memory = 357
# can_sample_self.memory = 357
# 5776304.5
# can_sample_self.memory = 358
# can_sample_self.memory = 358
# 3720219.25
# can_sample_self.memory = 359
# can_sample_self.memory = 359
# 2239389.75
# can_sample_self.memory = 360
# can_sample_self.memory = 360
# 1595274.125
# can_sample_self.memory = 361
# can_sample_self.memory = 361
# 1590436.25
# can_sample_self.memory = 362
# can_sample_self.memory = 362
# 34762232.0
# can_sample_self.memory = 363
# can_sample_self.memory = 363
# 35345768.0
# can_sample_self.memory = 364
# can_sample_self.memory = 364
# 30570076.0
# can_sample_self.memory = 365
# can_sample_self.memory = 365
# 24857896.0
# can_sample_self.memory = 366
# can_sample_self.memory = 366
# 16299360.0
# can_sample_self.memory = 367
# can_sample_self.memory = 367
# 9290569.0
# can_sample_self.memory = 368
# can_sample_self.memory = 368
# 10029487.0
# can_sample_self.memory = 369
# can_sample_self.memory = 369
# 2752579.0
# can_sample_self.memory = 370
# can_sample_self.memory = 370
# 3405988.25
# can_sample_self.memory = 371
# can_sample_self.memory = 371
# 7997517.5
# can_sample_self.memory = 372
# can_sample_self.memory = 372
# 12808483.0
# can_sample_self.memory = 373
# can_sample_self.memory = 373
# 13855658.0
# can_sample_self.memory = 374
# can_sample_self.memory = 374
# 11858585.0
# can_sample_self.memory = 375
# can_sample_self.memory = 375
# 10494506.0
# can_sample_self.memory = 376
# can_sample_self.memory = 376
# 5999563.0
# can_sample_self.memory = 377
# can_sample_self.memory = 377
#   6%|█████▎                                                                           | 13/200 [00:12<02:40,  1.16it/s]
# 3672106.25
# can_sample_self.memory = 378
# can_sample_self.memory = 378
# 672283.375
# can_sample_self.memory = 379
# can_sample_self.memory = 379
# 1696216.0
# can_sample_self.memory = 380
# can_sample_self.memory = 380
# 3149018.0
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 381
# can_sample_self.memory = 381
# 2996269.25
# can_sample_self.memory = 382
# can_sample_self.memory = 382
# 2642430.5
# can_sample_self.memory = 383
# can_sample_self.memory = 383
# 2002696.625
# can_sample_self.memory = 384
# can_sample_self.memory = 384
# 1489426.75
# can_sample_self.memory = 385
# can_sample_self.memory = 385
# 1692573.375
# can_sample_self.memory = 386
# can_sample_self.memory = 386
#   7%|█████▋                                                                           | 14/200 [00:12<02:19,  1.33it/s]
# 1415853.0
# can_sample_self.memory = 387
# can_sample_self.memory = 387
# 17030168.0
# can_sample_self.memory = 388
# can_sample_self.memory = 388
# 16680293.0
# can_sample_self.memory = 389
# can_sample_self.memory = 389
# 14665839.0
# <<< episode >>>
#   8%|██████                                                                           | 15/200 [00:12<01:47,  1.71it/s]
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 390
# can_sample_self.memory = 390
# 9290231.0
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 391
# can_sample_self.memory = 391
# 7906792.0
# can_sample_self.memory = 392
# can_sample_self.memory = 392
# 8511752.0
# can_sample_self.memory = 393
# can_sample_self.memory = 393
# 9984770.0
# can_sample_self.memory = 394
# can_sample_self.memory = 394
# 9117038.0
# can_sample_self.memory = 395
# can_sample_self.memory = 395
# 8242476.5
# can_sample_self.memory = 396
# can_sample_self.memory = 396
# 1481299.125
# can_sample_self.memory = 397
# can_sample_self.memory = 397
# 950045.625
# can_sample_self.memory = 398
# can_sample_self.memory = 398
# 608150.6875
# can_sample_self.memory = 399
# can_sample_self.memory = 399
# 1207343.375
# can_sample_self.memory = 400
# can_sample_self.memory = 400
# 1096141.125
# can_sample_self.memory = 401
# can_sample_self.memory = 401
# 1478952.875
# can_sample_self.memory = 402
# can_sample_self.memory = 402
# 1262674.125
# can_sample_self.memory = 403
# can_sample_self.memory = 403
# 885632.875
# can_sample_self.memory = 404
# can_sample_self.memory = 404
# 705347.25
# can_sample_self.memory = 405
# can_sample_self.memory = 405
# 747080.875
# can_sample_self.memory = 406
# can_sample_self.memory = 406
# 889540.125
# can_sample_self.memory = 407
# can_sample_self.memory = 407
# 330548.34375
# can_sample_self.memory = 408
# can_sample_self.memory = 408
# 774374.4375
# can_sample_self.memory = 409
# can_sample_self.memory = 409
# 399514.21875
# can_sample_self.memory = 410
# can_sample_self.memory = 410
# 1821773.375
# can_sample_self.memory = 411
# can_sample_self.memory = 411
# 7760613.5
# can_sample_self.memory = 412
# can_sample_self.memory = 412
# 7333156.0
# can_sample_self.memory = 413
# can_sample_self.memory = 413
# 4572944.5
# can_sample_self.memory = 414
# can_sample_self.memory = 414
# 1343483.0
# can_sample_self.memory = 415
# can_sample_self.memory = 415
# 847639.625
# can_sample_self.memory = 416
# can_sample_self.memory = 416
# 344435.34375
# can_sample_self.memory = 417
# can_sample_self.memory = 417
# 3406248.0
# can_sample_self.memory = 418
# can_sample_self.memory = 418
# 2502547.5
# can_sample_self.memory = 419
# can_sample_self.memory = 419
# 1663992.0
# can_sample_self.memory = 420
# can_sample_self.memory = 420
# 2815399.75
# can_sample_self.memory = 421
# can_sample_self.memory = 421
# 2420053.0
# can_sample_self.memory = 422
# can_sample_self.memory = 422
# 2180819.25
# can_sample_self.memory = 423
# can_sample_self.memory = 423
# 1967432.75
# can_sample_self.memory = 424
# can_sample_self.memory = 424
# 1762336.0
# can_sample_self.memory = 425
# can_sample_self.memory = 425
# 1067328.0
# can_sample_self.memory = 426
# can_sample_self.memory = 426
# 1064056.0
# can_sample_self.memory = 427
# can_sample_self.memory = 427
# 462109.3125
# can_sample_self.memory = 428
# can_sample_self.memory = 428
# 196022.5
# can_sample_self.memory = 429
# can_sample_self.memory = 429
# 383738.9375
# can_sample_self.memory = 430
# can_sample_self.memory = 430
# 457978.3125
# can_sample_self.memory = 431
# can_sample_self.memory = 431
# 1109020.125
# can_sample_self.memory = 432
# can_sample_self.memory = 432
# 415541.71875
# can_sample_self.memory = 433
# can_sample_self.memory = 433
# 534441.875
# can_sample_self.memory = 434
# can_sample_self.memory = 434
# 1343662.375
# can_sample_self.memory = 435
# can_sample_self.memory = 435
# 817177.1875
# can_sample_self.memory = 436
# can_sample_self.memory = 436
# 749736.125
# can_sample_self.memory = 437
# can_sample_self.memory = 437
# 871885.875
# can_sample_self.memory = 438
# can_sample_self.memory = 438
# 1547868.125
# can_sample_self.memory = 439
# can_sample_self.memory = 439
# 1129164.0
# can_sample_self.memory = 440
# can_sample_self.memory = 440
# 1167713.75
# can_sample_self.memory = 441
# can_sample_self.memory = 441
# 557505.6875
# can_sample_self.memory = 442
# can_sample_self.memory = 442
#   8%|██████▍                                                                          | 16/200 [00:15<03:14,  1.06s/it]
# 473510.625
# can_sample_self.memory = 443
# can_sample_self.memory = 443
# 500708.90625
# can_sample_self.memory = 444
# can_sample_self.memory = 444
# 309938.125
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 445
# can_sample_self.memory = 445
# 246064.828125
# can_sample_self.memory = 446
# can_sample_self.memory = 446
# 243152.578125
# can_sample_self.memory = 447
# can_sample_self.memory = 447
# 168651.0
# can_sample_self.memory = 448
# can_sample_self.memory = 448
# 201275.640625
# can_sample_self.memory = 449
# can_sample_self.memory = 449
# 6063694.5
# can_sample_self.memory = 450
# can_sample_self.memory = 450
# 153179.609375
# can_sample_self.memory = 451
# can_sample_self.memory = 451
# 414177.96875
# can_sample_self.memory = 452
# can_sample_self.memory = 452
# 222285.75
# can_sample_self.memory = 453
# can_sample_self.memory = 453
# 197771.390625
# can_sample_self.memory = 454
# can_sample_self.memory = 454
# 405284.875
# can_sample_self.memory = 455
# can_sample_self.memory = 455
# 6920341.5
# can_sample_self.memory = 456
# can_sample_self.memory = 456
# 7136596.5
# can_sample_self.memory = 457
# can_sample_self.memory = 457
# 5821883.5
# can_sample_self.memory = 458
# can_sample_self.memory = 458
# 5307263.5
# can_sample_self.memory = 459
# can_sample_self.memory = 459
# 170440.765625
# can_sample_self.memory = 460
# can_sample_self.memory = 460
# 3507538.75
# can_sample_self.memory = 461
# can_sample_self.memory = 461
#   8%|██████▉                                                                          | 17/200 [00:15<03:04,  1.01s/it]
# 2443632.75
# can_sample_self.memory = 462
# can_sample_self.memory = 462
# 2309814.5
# can_sample_self.memory = 463
# can_sample_self.memory = 463
# 1887583.75
# can_sample_self.memory = 464
# can_sample_self.memory = 464
# 1677413.875
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 465
# can_sample_self.memory = 465
# 1530407.5
# can_sample_self.memory = 466
# can_sample_self.memory = 466
# 2151472.25
# can_sample_self.memory = 467
# can_sample_self.memory = 467
# 1060381.75
# can_sample_self.memory = 468
# can_sample_self.memory = 468
# 692530.8125
# can_sample_self.memory = 469
# can_sample_self.memory = 469
# 521325.65625
# can_sample_self.memory = 470
# can_sample_self.memory = 470
# 1179946.875
# can_sample_self.memory = 471
# can_sample_self.memory = 471
# 508391.0625
# can_sample_self.memory = 472
# can_sample_self.memory = 472
# 977666.75
# can_sample_self.memory = 473
# can_sample_self.memory = 473
# 10012518.0
# can_sample_self.memory = 474
# can_sample_self.memory = 474
# 527368.75
# can_sample_self.memory = 475
# can_sample_self.memory = 475
# 790972.8125
#   9%|███████▎                                                                         | 18/200 [00:16<02:49,  1.07it/s]
# can_sample_self.memory = 476
# can_sample_self.memory = 476
# 1151889.0
# can_sample_self.memory = 477
# can_sample_self.memory = 477
# 1987512.125
# can_sample_self.memory = 478
# can_sample_self.memory = 478
# 13125493.0
# can_sample_self.memory = 479
# can_sample_self.memory = 479
# 12633084.0
# can_sample_self.memory = 480
# can_sample_self.memory = 480
# 11453396.0
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 481
# can_sample_self.memory = 481
# 8819443.0
# can_sample_self.memory = 482
# can_sample_self.memory = 482
# 9020220.0
# can_sample_self.memory = 483
# can_sample_self.memory = 483
# 7604081.0
# can_sample_self.memory = 484
# can_sample_self.memory = 484
# 5866318.0
# can_sample_self.memory = 485
# can_sample_self.memory = 485
# 2318208.0
# can_sample_self.memory = 486
# can_sample_self.memory = 486
# 4894665.0
# can_sample_self.memory = 487
# can_sample_self.memory = 487
# 1304441.125
# can_sample_self.memory = 488
# can_sample_self.memory = 488
# 3483202.5
# can_sample_self.memory = 489
# can_sample_self.memory = 489
# 4199247.0
# can_sample_self.memory = 490
# can_sample_self.memory = 490
# 5578382.0
# can_sample_self.memory = 491
# can_sample_self.memory = 491
# 5550746.5
# can_sample_self.memory = 492
# can_sample_self.memory = 492
# 5430184.5
# can_sample_self.memory = 493
# can_sample_self.memory = 493
# 4429474.0
# can_sample_self.memory = 494
# can_sample_self.memory = 494
# 2066770.25
# can_sample_self.memory = 495
# can_sample_self.memory = 495
# 2598411.0
# can_sample_self.memory = 496
# can_sample_self.memory = 496
# 2541288.5
# can_sample_self.memory = 497
# can_sample_self.memory = 497
# 2755339.0
# can_sample_self.memory = 498
# can_sample_self.memory = 498
# 3472962.5
# can_sample_self.memory = 499
# can_sample_self.memory = 499
# 2510293.75
# can_sample_self.memory = 500
# can_sample_self.memory = 500
# 2181429.5
# can_sample_self.memory = 501
# can_sample_self.memory = 501
# 2221858.25
# can_sample_self.memory = 502
# can_sample_self.memory = 502
# 1872099.5
# can_sample_self.memory = 503
# can_sample_self.memory = 503
#  10%|███████▋                                                                         | 19/200 [00:17<02:57,  1.02it/s]
# 1278077.0
# can_sample_self.memory = 504
# can_sample_self.memory = 504
# 4337212.0
# can_sample_self.memory = 505
# can_sample_self.memory = 505
# 6230499.5
# can_sample_self.memory = 506
# can_sample_self.memory = 506
# 680851.75
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 507
# can_sample_self.memory = 507
# 631272.9375
# can_sample_self.memory = 508
# can_sample_self.memory = 508
# 572406.1875
# can_sample_self.memory = 509
# can_sample_self.memory = 509
# 555600.0
# can_sample_self.memory = 510
# can_sample_self.memory = 510
# 43532.2265625
# can_sample_self.memory = 511
# can_sample_self.memory = 511
# 309974.125
# can_sample_self.memory = 512
# can_sample_self.memory = 512
# 99003.328125
# can_sample_self.memory = 513
# can_sample_self.memory = 513
# 333341.09375
# can_sample_self.memory = 514
# can_sample_self.memory = 514
# 158054.828125
# can_sample_self.memory = 515
# can_sample_self.memory = 515
# 277210.9375
# can_sample_self.memory = 516
# can_sample_self.memory = 516
# 123358.2109375
# can_sample_self.memory = 517
# can_sample_self.memory = 517
# 135424.84375
# can_sample_self.memory = 518
# can_sample_self.memory = 518
# 74844.203125
# can_sample_self.memory = 519
# can_sample_self.memory = 519
# 192741.90625
# can_sample_self.memory = 520
# can_sample_self.memory = 520
# 286544.53125
# can_sample_self.memory = 521
# can_sample_self.memory = 521
# 381786.03125
# can_sample_self.memory = 522
# can_sample_self.memory = 522
# 78600.3828125
# can_sample_self.memory = 523
# can_sample_self.memory = 523
# 98985.375
# can_sample_self.memory = 524
# can_sample_self.memory = 524
# 36879.625
# can_sample_self.memory = 525
# can_sample_self.memory = 525
# 193286.8125
# can_sample_self.memory = 526
# can_sample_self.memory = 526
# 122929.8828125
# can_sample_self.memory = 527
# can_sample_self.memory = 527
# 281521.46875
# can_sample_self.memory = 528
# can_sample_self.memory = 528
# 394851.90625
# can_sample_self.memory = 529
# can_sample_self.memory = 529
# 2058008.125
# can_sample_self.memory = 530
# can_sample_self.memory = 530
# 3667546.0
# can_sample_self.memory = 531
# can_sample_self.memory = 531
# 3651612.25
# can_sample_self.memory = 532
# can_sample_self.memory = 532
# 3828765.25
# can_sample_self.memory = 533
# can_sample_self.memory = 533
# 2010555.75
# can_sample_self.memory = 534
# can_sample_self.memory = 534
# 3397436.5
# can_sample_self.memory = 535
# can_sample_self.memory = 535
#  10%|████████                                                                         | 20/200 [00:18<03:09,  1.05s/it]
# 1449582.75
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 536
# can_sample_self.memory = 536
# 948357.4375
# can_sample_self.memory = 537
# can_sample_self.memory = 537
# 505434.8125
# can_sample_self.memory = 538
# can_sample_self.memory = 538
# 519916.40625
# can_sample_self.memory = 539
# can_sample_self.memory = 539
# 112253.34375
# can_sample_self.memory = 540
# can_sample_self.memory = 540
# 275099.59375
# can_sample_self.memory = 541
# can_sample_self.memory = 541
# 152840.59375
# can_sample_self.memory = 542
# can_sample_self.memory = 542
# 264579.1875
# can_sample_self.memory = 543
# can_sample_self.memory = 543
# 203376.15625
# can_sample_self.memory = 544
# can_sample_self.memory = 544
# 770138.375
# can_sample_self.memory = 545
# can_sample_self.memory = 545
# 310961.3125
# can_sample_self.memory = 546
# can_sample_self.memory = 546
# 488152.34375
# can_sample_self.memory = 547
# can_sample_self.memory = 547
# 518785.34375
# can_sample_self.memory = 548
# can_sample_self.memory = 548
# 18288.572265625
# can_sample_self.memory = 549
# can_sample_self.memory = 549
# 252882.625
# can_sample_self.memory = 550
# can_sample_self.memory = 550
# 262369.21875
# can_sample_self.memory = 551
# can_sample_self.memory = 551
# 301675.34375
# can_sample_self.memory = 552
# can_sample_self.memory = 552
# 153204.296875
# can_sample_self.memory = 553
# can_sample_self.memory = 553
# 186489.890625
# can_sample_self.memory = 554
# can_sample_self.memory = 554
# 111265.25
# can_sample_self.memory = 555
# can_sample_self.memory = 555
# 5757175.0
# can_sample_self.memory = 556
# can_sample_self.memory = 556
# 43352.58203125
# can_sample_self.memory = 557
# can_sample_self.memory = 557
# 360575.4375
# can_sample_self.memory = 558
# can_sample_self.memory = 558
# 370161.46875
#  10%|████████▌                                                                        | 21/200 [00:20<03:15,  1.09s/it]
# can_sample_self.memory = 559
# can_sample_self.memory = 559
# 314837.0625
# can_sample_self.memory = 560
# can_sample_self.memory = 560
# 291766.46875
# can_sample_self.memory = 561
# can_sample_self.memory = 561
# 167080.59375
# can_sample_self.memory = 562
# can_sample_self.memory = 562
# 1612900.25
# <<< episode >>>
#  11%|████████▉                                                                        | 22/200 [00:20<02:31,  1.18it/s]
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 563
# can_sample_self.memory = 563
# 1433642.5
# can_sample_self.memory = 564
# can_sample_self.memory = 564
# 1011233.875
# can_sample_self.memory = 565
# can_sample_self.memory = 565
# 331627.75
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 566
# can_sample_self.memory = 566
# 1126271.5
# can_sample_self.memory = 567
# can_sample_self.memory = 567
# 924737.1875
# can_sample_self.memory = 568
# can_sample_self.memory = 568
# 1458115.375
# can_sample_self.memory = 569
# can_sample_self.memory = 569
# 1250145.25
# can_sample_self.memory = 570
# can_sample_self.memory = 570
# 647482.8125
# can_sample_self.memory = 571
# can_sample_self.memory = 571
# 354149.15625
# can_sample_self.memory = 572
# can_sample_self.memory = 572
# 4273553.0
# can_sample_self.memory = 573
# can_sample_self.memory = 573
# 4431808.5
# can_sample_self.memory = 574
# can_sample_self.memory = 574
# 4098698.5
# can_sample_self.memory = 575
# can_sample_self.memory = 575
# 2790360.5
# can_sample_self.memory = 576
# can_sample_self.memory = 576
# 954550.0
#  12%|█████████▎                                                                       | 23/200 [00:21<02:23,  1.23it/s]
# can_sample_self.memory = 577
# can_sample_self.memory = 577
# 1817647.625
# can_sample_self.memory = 578
# can_sample_self.memory = 578
# 1603105.25
# can_sample_self.memory = 579
# can_sample_self.memory = 579
# 2205655.25
# can_sample_self.memory = 580
# can_sample_self.memory = 580
# 12442600.0
# can_sample_self.memory = 581
# can_sample_self.memory = 581
# 1036433.125
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 582
# can_sample_self.memory = 582
# 884409.375
# can_sample_self.memory = 583
# can_sample_self.memory = 583
# 1201549.875
# can_sample_self.memory = 584
# can_sample_self.memory = 584
# 1931578.125
# can_sample_self.memory = 585
# can_sample_self.memory = 585
# 2690033.25
# can_sample_self.memory = 586
# can_sample_self.memory = 586
# nan
# can_sample_self.memory = 587
# can_sample_self.memory = 587
# nan
# can_sample_self.memory = 588
# can_sample_self.memory = 588
# nan
# can_sample_self.memory = 589
# can_sample_self.memory = 589
# nan
# can_sample_self.memory = 590
# can_sample_self.memory = 590
# nan
# can_sample_self.memory = 591
# can_sample_self.memory = 591
# nan
# can_sample_self.memory = 592
# can_sample_self.memory = 592
# nan
# can_sample_self.memory = 593
# can_sample_self.memory = 593
# nan
# can_sample_self.memory = 594
# can_sample_self.memory = 594
# nan
# can_sample_self.memory = 595
# can_sample_self.memory = 595
# nan
# can_sample_self.memory = 596
# can_sample_self.memory = 596
# nan
# can_sample_self.memory = 597
# can_sample_self.memory = 597
# nan
# can_sample_self.memory = 598
# can_sample_self.memory = 598
# nan
# can_sample_self.memory = 599
# can_sample_self.memory = 599
# nan
# can_sample_self.memory = 600
# can_sample_self.memory = 600
# nan
# can_sample_self.memory = 601
# can_sample_self.memory = 601
# nan
# can_sample_self.memory = 602
# can_sample_self.memory = 602
# nan
# can_sample_self.memory = 603
# can_sample_self.memory = 603
# nan
# can_sample_self.memory = 604
# can_sample_self.memory = 604
# nan
# can_sample_self.memory = 605
# can_sample_self.memory = 605
# nan
# can_sample_self.memory = 606
# can_sample_self.memory = 606
# nan
# can_sample_self.memory = 607
# can_sample_self.memory = 607
# nan
# can_sample_self.memory = 608
# can_sample_self.memory = 608
# nan
# can_sample_self.memory = 609
# can_sample_self.memory = 609
# nan
# can_sample_self.memory = 610
# can_sample_self.memory = 610
# nan
#  12%|█████████▋                                                                       | 24/200 [00:22<02:51,  1.03it/s]
# can_sample_self.memory = 611
# can_sample_self.memory = 611
# nan
# can_sample_self.memory = 612
# can_sample_self.memory = 612
# nan
# can_sample_self.memory = 613
# can_sample_self.memory = 613
# nan
# can_sample_self.memory = 614
# can_sample_self.memory = 614
# nan
# can_sample_self.memory = 615
# can_sample_self.memory = 615
# nan
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 616
# can_sample_self.memory = 616
# nan
# can_sample_self.memory = 617
# can_sample_self.memory = 617
# nan
# can_sample_self.memory = 618
# can_sample_self.memory = 618
# nan
# can_sample_self.memory = 619
# can_sample_self.memory = 619
# nan
# can_sample_self.memory = 620
# can_sample_self.memory = 620
# nan
# can_sample_self.memory = 621
# can_sample_self.memory = 621
# nan
# can_sample_self.memory = 622
# can_sample_self.memory = 622
# nan
# can_sample_self.memory = 623
# can_sample_self.memory = 623
# nan
# can_sample_self.memory = 624
# can_sample_self.memory = 624
# nan
# can_sample_self.memory = 625
# can_sample_self.memory = 625
# nan
# can_sample_self.memory = 626
# can_sample_self.memory = 626
# nan
# can_sample_self.memory = 627
# can_sample_self.memory = 627
# nan
# can_sample_self.memory = 628
# can_sample_self.memory = 628
# nan
# can_sample_self.memory = 629
# can_sample_self.memory = 629
# nan
# can_sample_self.memory = 630
# can_sample_self.memory = 630
# nan
# can_sample_self.memory = 631
# can_sample_self.memory = 631
# nan
# can_sample_self.memory = 632
# can_sample_self.memory = 632
# nan
# can_sample_self.memory = 633
# can_sample_self.memory = 633
# nan
# can_sample_self.memory = 634
# can_sample_self.memory = 634
# nan
# can_sample_self.memory = 635
# can_sample_self.memory = 635
# nan
# can_sample_self.memory = 636
# can_sample_self.memory = 636
# nan
# can_sample_self.memory = 637
# can_sample_self.memory = 637
# nan
# can_sample_self.memory = 638
# can_sample_self.memory = 638
# nan
# can_sample_self.memory = 639
# can_sample_self.memory = 639
# nan
# can_sample_self.memory = 640
# can_sample_self.memory = 640
# nan
# can_sample_self.memory = 641
# can_sample_self.memory = 641
# nan
# can_sample_self.memory = 642
# can_sample_self.memory = 642
# nan
# can_sample_self.memory = 643
# can_sample_self.memory = 643
# nan
# can_sample_self.memory = 644
# can_sample_self.memory = 644
# nan
# can_sample_self.memory = 645
# can_sample_self.memory = 645
# nan
# can_sample_self.memory = 646
# can_sample_self.memory = 646
# nan
# can_sample_self.memory = 647
# can_sample_self.memory = 647
# nan
# can_sample_self.memory = 648
# can_sample_self.memory = 648
# nan
# can_sample_self.memory = 649
# can_sample_self.memory = 649
# nan
# can_sample_self.memory = 650
# can_sample_self.memory = 650
# nan
# can_sample_self.memory = 651
# can_sample_self.memory = 651
# nan
# can_sample_self.memory = 652
# can_sample_self.memory = 652
# nan
# can_sample_self.memory = 653
# can_sample_self.memory = 653
# nan
# can_sample_self.memory = 654
# can_sample_self.memory = 654
# nan
# can_sample_self.memory = 655
# can_sample_self.memory = 655
# nan
# can_sample_self.memory = 656
# can_sample_self.memory = 656
# nan
# can_sample_self.memory = 657
# can_sample_self.memory = 657
# nan
# can_sample_self.memory = 658
# can_sample_self.memory = 658
# nan
# can_sample_self.memory = 659
# can_sample_self.memory = 659
# nan
# can_sample_self.memory = 660
# can_sample_self.memory = 660
# nan
# can_sample_self.memory = 661
# can_sample_self.memory = 661
# nan
# can_sample_self.memory = 662
# can_sample_self.memory = 662
# nan
# can_sample_self.memory = 663
# can_sample_self.memory = 663
# nan
# can_sample_self.memory = 664
# can_sample_self.memory = 664
# nan
# can_sample_self.memory = 665
# can_sample_self.memory = 665
# nan
# can_sample_self.memory = 666
# can_sample_self.memory = 666
# nan
# can_sample_self.memory = 667
# can_sample_self.memory = 667
# nan
# can_sample_self.memory = 668
# can_sample_self.memory = 668
# nan
# can_sample_self.memory = 669
# can_sample_self.memory = 669
# nan
# can_sample_self.memory = 670
# can_sample_self.memory = 670
# nan
# can_sample_self.memory = 671
# can_sample_self.memory = 671
# nan
# can_sample_self.memory = 672
# can_sample_self.memory = 672
# nan
# can_sample_self.memory = 673
#  12%|██████████▏                                                                      | 25/200 [00:24<03:59,  1.37s/it]
# can_sample_self.memory = 673
# nan
# can_sample_self.memory = 674
# can_sample_self.memory = 674
# nan
# can_sample_self.memory = 675
# can_sample_self.memory = 675
# nan
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 676
# can_sample_self.memory = 676
# nan
# can_sample_self.memory = 677
# can_sample_self.memory = 677
# nan
# can_sample_self.memory = 678
# can_sample_self.memory = 678
# nan
# can_sample_self.memory = 679
# can_sample_self.memory = 679
# nan
# can_sample_self.memory = 680
# can_sample_self.memory = 680
# nan
# can_sample_self.memory = 681
# can_sample_self.memory = 681
# nan
# can_sample_self.memory = 682
# can_sample_self.memory = 682
# nan
# can_sample_self.memory = 683
# can_sample_self.memory = 683
# nan
# can_sample_self.memory = 684
# can_sample_self.memory = 684
# nan
# can_sample_self.memory = 685
# can_sample_self.memory = 685
# nan
# can_sample_self.memory = 686
# can_sample_self.memory = 686
# nan
# can_sample_self.memory = 687
# can_sample_self.memory = 687
# nan
# can_sample_self.memory = 688
# can_sample_self.memory = 688
# nan
# can_sample_self.memory = 689
# can_sample_self.memory = 689
# nan
# can_sample_self.memory = 690
# can_sample_self.memory = 690
# nan
# can_sample_self.memory = 691
# can_sample_self.memory = 691
# nan
# can_sample_self.memory = 692
# can_sample_self.memory = 692
# nan
# can_sample_self.memory = 693
# can_sample_self.memory = 693
# nan
# can_sample_self.memory = 694
# can_sample_self.memory = 694
# nan
# can_sample_self.memory = 695
# can_sample_self.memory = 695
# nan
# can_sample_self.memory = 696
# can_sample_self.memory = 696
# nan
# can_sample_self.memory = 697
# can_sample_self.memory = 697
# nan
# can_sample_self.memory = 698
# can_sample_self.memory = 698
# nan
# can_sample_self.memory = 699
# can_sample_self.memory = 699
# nan
# can_sample_self.memory = 700
# can_sample_self.memory = 700
# nan
# can_sample_self.memory = 701
# can_sample_self.memory = 701
# nan
# can_sample_self.memory = 702
# can_sample_self.memory = 702
# nan
# can_sample_self.memory = 703
# can_sample_self.memory = 703
# nan
# can_sample_self.memory = 704
# can_sample_self.memory = 704
# nan
# can_sample_self.memory = 705
# can_sample_self.memory = 705
# nan
# can_sample_self.memory = 706
# can_sample_self.memory = 706
# nan
# can_sample_self.memory = 707
# can_sample_self.memory = 707
# nan
# can_sample_self.memory = 708
# can_sample_self.memory = 708
# nan
# can_sample_self.memory = 709
# can_sample_self.memory = 709
# nan
# can_sample_self.memory = 710
# can_sample_self.memory = 710
# nan
# can_sample_self.memory = 711
# can_sample_self.memory = 711
# nan
# can_sample_self.memory = 712
# can_sample_self.memory = 712
# nan
# can_sample_self.memory = 713
# can_sample_self.memory = 713
# nan
# can_sample_self.memory = 714
# can_sample_self.memory = 714
# nan
# can_sample_self.memory = 715
# can_sample_self.memory = 715
# nan
# can_sample_self.memory = 716
# can_sample_self.memory = 716
# nan
# can_sample_self.memory = 717
# can_sample_self.memory = 717
# nan
# can_sample_self.memory = 718
# can_sample_self.memory = 718
# nan
# can_sample_self.memory = 719
# can_sample_self.memory = 719
# nan
# can_sample_self.memory = 720
# can_sample_self.memory = 720
# nan
# can_sample_self.memory = 721
# can_sample_self.memory = 721
# nan
# can_sample_self.memory = 722
# can_sample_self.memory = 722
# nan
# can_sample_self.memory = 723
# can_sample_self.memory = 723
# nan
# can_sample_self.memory = 724
# can_sample_self.memory = 724
# nan
# can_sample_self.memory = 725
# can_sample_self.memory = 725
# nan
# can_sample_self.memory = 726
# can_sample_self.memory = 726
# nan
# can_sample_self.memory = 727
# can_sample_self.memory = 727
# nan
# can_sample_self.memory = 728
# can_sample_self.memory = 728
# nan
# can_sample_self.memory = 729
# can_sample_self.memory = 729
# nan
# can_sample_self.memory = 730
# can_sample_self.memory = 730
# nan
# can_sample_self.memory = 731
# can_sample_self.memory = 731
# nan
# can_sample_self.memory = 732
# can_sample_self.memory = 732
#  13%|██████████▌                                                                      | 26/200 [00:27<04:45,  1.64s/it]
# nan
# can_sample_self.memory = 733
# can_sample_self.memory = 733
# nan
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 734
# can_sample_self.memory = 734
# nan
# can_sample_self.memory = 735
# can_sample_self.memory = 735
# nan
# can_sample_self.memory = 736
# can_sample_self.memory = 736
# nan
# can_sample_self.memory = 737
# can_sample_self.memory = 737
# nan
# can_sample_self.memory = 738
# can_sample_self.memory = 738
# nan
# can_sample_self.memory = 739
# can_sample_self.memory = 739
# nan
# can_sample_self.memory = 740
# can_sample_self.memory = 740
# nan
# can_sample_self.memory = 741
# can_sample_self.memory = 741
# nan
# can_sample_self.memory = 742
# can_sample_self.memory = 742
# nan
# can_sample_self.memory = 743
# can_sample_self.memory = 743
# nan
# can_sample_self.memory = 744
# can_sample_self.memory = 744
# nan
# can_sample_self.memory = 745
# can_sample_self.memory = 745
# nan
# can_sample_self.memory = 746
# can_sample_self.memory = 746
# nan
# can_sample_self.memory = 747
# can_sample_self.memory = 747
# nan
# can_sample_self.memory = 748
# can_sample_self.memory = 748
# nan
# can_sample_self.memory = 749
# can_sample_self.memory = 749
# nan
# can_sample_self.memory = 750
# can_sample_self.memory = 750
# nan
# can_sample_self.memory = 751
# can_sample_self.memory = 751
# nan
# can_sample_self.memory = 752
# can_sample_self.memory = 752
# nan
# can_sample_self.memory = 753
# can_sample_self.memory = 753
# nan
# can_sample_self.memory = 754
# can_sample_self.memory = 754
# nan
# can_sample_self.memory = 755
# can_sample_self.memory = 755
# nan
# can_sample_self.memory = 756
# can_sample_self.memory = 756
# nan
# can_sample_self.memory = 757
# can_sample_self.memory = 757
# nan
# can_sample_self.memory = 758
# can_sample_self.memory = 758
# nan
# can_sample_self.memory = 759
# can_sample_self.memory = 759
# nan
# can_sample_self.memory = 760
# can_sample_self.memory = 760
# nan
# can_sample_self.memory = 761
# can_sample_self.memory = 761
# nan
# can_sample_self.memory = 762
# can_sample_self.memory = 762
# nan
# can_sample_self.memory = 763
# can_sample_self.memory = 763
# nan
# can_sample_self.memory = 764
# can_sample_self.memory = 764
# nan
# can_sample_self.memory = 765
# can_sample_self.memory = 765
# nan
# can_sample_self.memory = 766
# can_sample_self.memory = 766
# nan
# can_sample_self.memory = 767
# can_sample_self.memory = 767
# nan
# can_sample_self.memory = 768
# can_sample_self.memory = 768
# nan
# can_sample_self.memory = 769
# can_sample_self.memory = 769
# nan
# can_sample_self.memory = 770
# can_sample_self.memory = 770
# nan
# can_sample_self.memory = 771
# can_sample_self.memory = 771
# nan
# can_sample_self.memory = 772
# can_sample_self.memory = 772
# nan
# can_sample_self.memory = 773
# can_sample_self.memory = 773
# nan
# can_sample_self.memory = 774
# can_sample_self.memory = 774
# nan
# can_sample_self.memory = 775
# can_sample_self.memory = 775
# nan
# can_sample_self.memory = 776
# can_sample_self.memory = 776
# nan
# can_sample_self.memory = 777
# can_sample_self.memory = 777
# nan
# can_sample_self.memory = 778
# can_sample_self.memory = 778
# nan
# can_sample_self.memory = 779
# can_sample_self.memory = 779
# nan
# can_sample_self.memory = 780
# can_sample_self.memory = 780
# nan
# can_sample_self.memory = 781
# can_sample_self.memory = 781
# nan
# can_sample_self.memory = 782
# can_sample_self.memory = 782
# nan
# can_sample_self.memory = 783
# can_sample_self.memory = 783
# nan
# can_sample_self.memory = 784
# can_sample_self.memory = 784
# nan
# can_sample_self.memory = 785
# can_sample_self.memory = 785
# nan
# can_sample_self.memory = 786
# can_sample_self.memory = 786
# nan
# can_sample_self.memory = 787
# can_sample_self.memory = 787
# nan
# can_sample_self.memory = 788
# can_sample_self.memory = 788
# nan
# can_sample_self.memory = 789
# can_sample_self.memory = 789
# nan
# can_sample_self.memory = 790
# can_sample_self.memory = 790
# nan
# can_sample_self.memory = 791
# can_sample_self.memory = 791
# nan
# can_sample_self.memory = 792
# can_sample_self.memory = 792
# nan
# can_sample_self.memory = 793
# can_sample_self.memory = 793
# nan
# can_sample_self.memory = 794
# can_sample_self.memory = 794
# nan
# can_sample_self.memory = 795
# can_sample_self.memory = 795
# nan
# can_sample_self.memory = 796
# can_sample_self.memory = 796
# nan
# can_sample_self.memory = 797
# can_sample_self.memory = 797
# nan
# can_sample_self.memory = 798
# can_sample_self.memory = 798
# nan
# can_sample_self.memory = 799
# can_sample_self.memory = 799
# nan
# can_sample_self.memory = 800
# can_sample_self.memory = 800
# nan
# can_sample_self.memory = 801
# can_sample_self.memory = 801
# nan
# can_sample_self.memory = 802
# can_sample_self.memory = 802
# nan
# can_sample_self.memory = 803
# can_sample_self.memory = 803
# nan
# can_sample_self.memory = 804
# can_sample_self.memory = 804
# nan
# can_sample_self.memory = 805
# can_sample_self.memory = 805
# nan
# can_sample_self.memory = 806
# can_sample_self.memory = 806
# nan
# can_sample_self.memory = 807
# can_sample_self.memory = 807
# nan
# can_sample_self.memory = 808
# can_sample_self.memory = 808
# nan
# can_sample_self.memory = 809
# can_sample_self.memory = 809
# nan
# can_sample_self.memory = 810
# can_sample_self.memory = 810
# nan
# can_sample_self.memory = 811
# can_sample_self.memory = 811
# nan
# can_sample_self.memory = 812
# can_sample_self.memory = 812
# nan
# can_sample_self.memory = 813
# can_sample_self.memory = 813
# nan
# can_sample_self.memory = 814
# can_sample_self.memory = 814
# nan
# can_sample_self.memory = 815
# can_sample_self.memory = 815
# nan
# can_sample_self.memory = 816
# can_sample_self.memory = 816
# nan
# can_sample_self.memory = 817
# can_sample_self.memory = 817
# nan
# can_sample_self.memory = 818
# can_sample_self.memory = 818
# nan
# can_sample_self.memory = 819
# can_sample_self.memory = 819
# nan
# can_sample_self.memory = 820
# can_sample_self.memory = 820
# nan
# can_sample_self.memory = 821
# can_sample_self.memory = 821
# nan
# can_sample_self.memory = 822
# can_sample_self.memory = 822
# nan
# can_sample_self.memory = 823
# can_sample_self.memory = 823
# nan
# can_sample_self.memory = 824
# can_sample_self.memory = 824
# nan
# can_sample_self.memory = 825
# can_sample_self.memory = 825
# nan
# can_sample_self.memory = 826
# can_sample_self.memory = 826
# nan
# can_sample_self.memory = 827
# can_sample_self.memory = 827
# nan
# can_sample_self.memory = 828
# can_sample_self.memory = 828
# nan
# can_sample_self.memory = 829
# can_sample_self.memory = 829
#  14%|██████████▉                                                                      | 27/200 [00:30<06:37,  2.30s/it]
# nan
# can_sample_self.memory = 830
# can_sample_self.memory = 830
# nan
# can_sample_self.memory = 831
# can_sample_self.memory = 831
# nan
# can_sample_self.memory = 832
# can_sample_self.memory = 832
# nan
# can_sample_self.memory = 833
# can_sample_self.memory = 833
# nan
# can_sample_self.memory = 834
# can_sample_self.memory = 834
# nan
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 835
# can_sample_self.memory = 835
# nan
# can_sample_self.memory = 836
# can_sample_self.memory = 836
# nan
# can_sample_self.memory = 837
# can_sample_self.memory = 837
# nan
# can_sample_self.memory = 838
# can_sample_self.memory = 838
# nan
# can_sample_self.memory = 839
# can_sample_self.memory = 839
# nan
# can_sample_self.memory = 840
# ...
# nan
# can_sample_self.memory = 12531
# can_sample_self.memory = 12531
# nan
# can_sample_self.memory = 12532
# can_sample_self.memory = 12532
# nan
# can_sample_self.memory = 12533
# can_sample_self.memory = 12533
# nan
# can_sample_self.memory = 12534
# can_sample_self.memory = 12534
# nan
# can_sample_self.memory = 12535
# can_sample_self.memory = 12535
# nan
# can_sample_self.memory = 12536
# can_sample_self.memory = 12536
# nan
# can_sample_self.memory = 12537
# can_sample_self.memory = 12537
# nan
# can_sample_self.memory = 12538
# can_sample_self.memory = 12538
# nan
# can_sample_self.memory = 12539
# can_sample_self.memory = 12539
# nan
# can_sample_self.memory = 12540
# can_sample_self.memory = 12540
# nan
# can_sample_self.memory = 12541
# can_sample_self.memory = 12541
# nan
# can_sample_self.memory = 12542
# can_sample_self.memory = 12542
# nan
# can_sample_self.memory = 12543
# can_sample_self.memory = 12543
# nan
# can_sample_self.memory = 12544
# can_sample_self.memory = 12544
# nan
# can_sample_self.memory = 12545
# can_sample_self.memory = 12545
# nan
# can_sample_self.memory = 12546
# can_sample_self.memory = 12546
# nan
# can_sample_self.memory = 12547
# can_sample_self.memory = 12547
# nan
# can_sample_self.memory = 12548
# can_sample_self.memory = 12548
# nan
# can_sample_self.memory = 12549
# can_sample_self.memory = 12549
# nan
# can_sample_self.memory = 12550
# can_sample_self.memory = 12550
# nan
# can_sample_self.memory = 12551
# can_sample_self.memory = 12551
# nan
# can_sample_self.memory = 12552
# can_sample_self.memory = 12552
# nan
# can_sample_self.memory = 12553
# can_sample_self.memory = 12553
# nan
# can_sample_self.memory = 12554
# can_sample_self.memory = 12554
# nan
# can_sample_self.memory = 12555
# can_sample_self.memory = 12555
# nan
# can_sample_self.memory = 12556
# can_sample_self.memory = 12556
# nan
# can_sample_self.memory = 12557
# can_sample_self.memory = 12557
# nan
# can_sample_self.memory = 12558
# can_sample_self.memory = 12558
# nan
# can_sample_self.memory = 12559
# can_sample_self.memory = 12559
# nan
# can_sample_self.memory = 12560
# can_sample_self.memory = 12560
# nan
# can_sample_self.memory = 12561
# can_sample_self.memory = 12561
# nan
# can_sample_self.memory = 12562
# can_sample_self.memory = 12562
# nan
# can_sample_self.memory = 12563
# can_sample_self.memory = 12563
# nan
# can_sample_self.memory = 12564
# can_sample_self.memory = 12564
# nan
# can_sample_self.memory = 12565
# can_sample_self.memory = 12565
# nan
# can_sample_self.memory = 12566
# can_sample_self.memory = 12566
# nan
# can_sample_self.memory = 12567
# can_sample_self.memory = 12567
# nan
# can_sample_self.memory = 12568
# can_sample_self.memory = 12568
# nan
# can_sample_self.memory = 12569
# can_sample_self.memory = 12569
# nan
# can_sample_self.memory = 12570
# can_sample_self.memory = 12570
# nan
# can_sample_self.memory = 12571
# can_sample_self.memory = 12571
# nan
# can_sample_self.memory = 12572
# can_sample_self.memory = 12572
# nan
# can_sample_self.memory = 12573
# can_sample_self.memory = 12573
# nan
# can_sample_self.memory = 12574
# can_sample_self.memory = 12574
# nan
# can_sample_self.memory = 12575
# can_sample_self.memory = 12575
# nan
# can_sample_self.memory = 12576
# can_sample_self.memory = 12576
# nan
# can_sample_self.memory = 12577
# can_sample_self.memory = 12577
# nan
# can_sample_self.memory = 12578
# can_sample_self.memory = 12578
# nan
# can_sample_self.memory = 12579
# can_sample_self.memory = 12579
# nan
# can_sample_self.memory = 12580
# can_sample_self.memory = 12580
# nan
# can_sample_self.memory = 12581
# can_sample_self.memory = 12581
# nan
# can_sample_self.memory = 12582
# can_sample_self.memory = 12582
# nan
# can_sample_self.memory = 12583
# can_sample_self.memory = 12583
# nan
# can_sample_self.memory = 12584
# can_sample_self.memory = 12584
# nan
# can_sample_self.memory = 12585
# can_sample_self.memory = 12585
# nan
# can_sample_self.memory = 12586
# can_sample_self.memory = 12586
# nan
# can_sample_self.memory = 12587
# can_sample_self.memory = 12587
# nan
# can_sample_self.memory = 12588
# can_sample_self.memory = 12588
# nan
# can_sample_self.memory = 12589
# can_sample_self.memory = 12589
# nan
# can_sample_self.memory = 12590
# can_sample_self.memory = 12590
# nan
# can_sample_self.memory = 12591
# can_sample_self.memory = 12591
# nan
# can_sample_self.memory = 12592
# can_sample_self.memory = 12592
# nan
# can_sample_self.memory = 12593
# can_sample_self.memory = 12593
# nan
# can_sample_self.memory = 12594
# can_sample_self.memory = 12594
# nan
# can_sample_self.memory = 12595
# can_sample_self.memory = 12595
# nan
# can_sample_self.memory = 12596
# can_sample_self.memory = 12596
# nan
# can_sample_self.memory = 12597
# can_sample_self.memory = 12597
# nan
# can_sample_self.memory = 12598
# can_sample_self.memory = 12598
# nan
# can_sample_self.memory = 12599
# can_sample_self.memory = 12599
# nan
# can_sample_self.memory = 12600
# can_sample_self.memory = 12600
# nan
# can_sample_self.memory = 12601
# can_sample_self.memory = 12601
# nan
# can_sample_self.memory = 12602
# can_sample_self.memory = 12602
# nan
# can_sample_self.memory = 12603
# can_sample_self.memory = 12603
# nan
# can_sample_self.memory = 12604
# can_sample_self.memory = 12604
# nan
# can_sample_self.memory = 12605
# can_sample_self.memory = 12605
# nan
# can_sample_self.memory = 12606
# can_sample_self.memory = 12606
# nan
# can_sample_self.memory = 12607
# can_sample_self.memory = 12607
# nan
# can_sample_self.memory = 12608
# can_sample_self.memory = 12608
# nan
# can_sample_self.memory = 12609
# can_sample_self.memory = 12609
# nan
# can_sample_self.memory = 12610
# can_sample_self.memory = 12610
# nan
# can_sample_self.memory = 12611
# can_sample_self.memory = 12611
# nan
# can_sample_self.memory = 12612
# can_sample_self.memory = 12612
# nan
# can_sample_self.memory = 12613
# can_sample_self.memory = 12613
# nan
# can_sample_self.memory = 12614
# can_sample_self.memory = 12614
# nan
# can_sample_self.memory = 12615
# can_sample_self.memory = 12615
# nan
# can_sample_self.memory = 12616
# can_sample_self.memory = 12616
# nan
#  98%|██████████████████████████████████████████████████████████████████████████████▊ | 197/200 [08:05<00:07,  2.41s/it]
# can_sample_self.memory = 12617
# can_sample_self.memory = 12617
# nan
# can_sample_self.memory = 12618
# can_sample_self.memory = 12618
# nan
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 12619
# can_sample_self.memory = 12619
# nan
# can_sample_self.memory = 12620
# can_sample_self.memory = 12620
# nan
# can_sample_self.memory = 12621
# can_sample_self.memory = 12621
# nan
# can_sample_self.memory = 12622
# can_sample_self.memory = 12622
# nan
# can_sample_self.memory = 12623
# can_sample_self.memory = 12623
# nan
# can_sample_self.memory = 12624
# can_sample_self.memory = 12624
# nan
# can_sample_self.memory = 12625
# can_sample_self.memory = 12625
# nan
# can_sample_self.memory = 12626
# can_sample_self.memory = 12626
# nan
# can_sample_self.memory = 12627
# can_sample_self.memory = 12627
# nan
# can_sample_self.memory = 12628
# can_sample_self.memory = 12628
# nan
# can_sample_self.memory = 12629
# can_sample_self.memory = 12629
# nan
# can_sample_self.memory = 12630
# can_sample_self.memory = 12630
# nan
# can_sample_self.memory = 12631
# can_sample_self.memory = 12631
# nan
# can_sample_self.memory = 12632
# can_sample_self.memory = 12632
# nan
# can_sample_self.memory = 12633
# can_sample_self.memory = 12633
# nan
# can_sample_self.memory = 12634
# can_sample_self.memory = 12634
# nan
# can_sample_self.memory = 12635
# can_sample_self.memory = 12635
# nan
# can_sample_self.memory = 12636
# can_sample_self.memory = 12636
# nan
# can_sample_self.memory = 12637
# can_sample_self.memory = 12637
# nan
# can_sample_self.memory = 12638
# can_sample_self.memory = 12638
# nan
# can_sample_self.memory = 12639
# can_sample_self.memory = 12639
# nan
# can_sample_self.memory = 12640
# can_sample_self.memory = 12640
# nan
# can_sample_self.memory = 12641
# can_sample_self.memory = 12641
# nan
# can_sample_self.memory = 12642
# can_sample_self.memory = 12642
# nan
# can_sample_self.memory = 12643
# can_sample_self.memory = 12643
# nan
# can_sample_self.memory = 12644
# can_sample_self.memory = 12644
# nan
# can_sample_self.memory = 12645
# can_sample_self.memory = 12645
# nan
# can_sample_self.memory = 12646
# can_sample_self.memory = 12646
# nan
# can_sample_self.memory = 12647
# can_sample_self.memory = 12647
# nan
# can_sample_self.memory = 12648
# can_sample_self.memory = 12648
# nan
# can_sample_self.memory = 12649
# can_sample_self.memory = 12649
# nan
# can_sample_self.memory = 12650
# can_sample_self.memory = 12650
# nan
# can_sample_self.memory = 12651
# can_sample_self.memory = 12651
# nan
# can_sample_self.memory = 12652
# can_sample_self.memory = 12652
# nan
# can_sample_self.memory = 12653
# can_sample_self.memory = 12653
# nan
# can_sample_self.memory = 12654
# can_sample_self.memory = 12654
# nan
# can_sample_self.memory = 12655
# can_sample_self.memory = 12655
# nan
# can_sample_self.memory = 12656
# can_sample_self.memory = 12656
# nan
# can_sample_self.memory = 12657
# can_sample_self.memory = 12657
# nan
# can_sample_self.memory = 12658
# can_sample_self.memory = 12658
# nan
# can_sample_self.memory = 12659
# can_sample_self.memory = 12659
# nan
# can_sample_self.memory = 12660
# can_sample_self.memory = 12660
# nan
# can_sample_self.memory = 12661
# can_sample_self.memory = 12661
# nan
# can_sample_self.memory = 12662
# can_sample_self.memory = 12662
# nan
# can_sample_self.memory = 12663
# can_sample_self.memory = 12663
# nan
# can_sample_self.memory = 12664
# can_sample_self.memory = 12664
# nan
# can_sample_self.memory = 12665
# can_sample_self.memory = 12665
# nan
# can_sample_self.memory = 12666
# can_sample_self.memory = 12666
# nan
# can_sample_self.memory = 12667
# can_sample_self.memory = 12667
# nan
# can_sample_self.memory = 12668
# can_sample_self.memory = 12668
# nan
# can_sample_self.memory = 12669
# can_sample_self.memory = 12669
# nan
# can_sample_self.memory = 12670
# can_sample_self.memory = 12670
# nan
# can_sample_self.memory = 12671
# can_sample_self.memory = 12671
# nan
# can_sample_self.memory = 12672
# can_sample_self.memory = 12672
# nan
# can_sample_self.memory = 12673
# can_sample_self.memory = 12673
# nan
# can_sample_self.memory = 12674
# can_sample_self.memory = 12674
# nan
# can_sample_self.memory = 12675
# can_sample_self.memory = 12675
# nan
# can_sample_self.memory = 12676
# can_sample_self.memory = 12676
# nan
# can_sample_self.memory = 12677
# can_sample_self.memory = 12677
# nan
# can_sample_self.memory = 12678
# can_sample_self.memory = 12678
# nan
# can_sample_self.memory = 12679
# can_sample_self.memory = 12679
# nan
# can_sample_self.memory = 12680
# can_sample_self.memory = 12680
# nan
# can_sample_self.memory = 12681
# can_sample_self.memory = 12681
# nan
# can_sample_self.memory = 12682
# can_sample_self.memory = 12682
# nan
# can_sample_self.memory = 12683
# can_sample_self.memory = 12683
# nan
# can_sample_self.memory = 12684
# can_sample_self.memory = 12684
# nan
# can_sample_self.memory = 12685
# can_sample_self.memory = 12685
# nan
# can_sample_self.memory = 12686
# can_sample_self.memory = 12686
# nan
# can_sample_self.memory = 12687
# can_sample_self.memory = 12687
#  99%|███████████████████████████████████████████████████████████████████████████████▏| 198/200 [08:08<00:04,  2.50s/it]
# nan
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 12688
# can_sample_self.memory = 12688
# nan
# can_sample_self.memory = 12689
# can_sample_self.memory = 12689
# nan
# can_sample_self.memory = 12690
# can_sample_self.memory = 12690
# nan
# can_sample_self.memory = 12691
# can_sample_self.memory = 12691
# nan
# can_sample_self.memory = 12692
# can_sample_self.memory = 12692
# nan
# can_sample_self.memory = 12693
# can_sample_self.memory = 12693
# nan
# can_sample_self.memory = 12694
# can_sample_self.memory = 12694
# nan
# can_sample_self.memory = 12695
# can_sample_self.memory = 12695
# nan
# can_sample_self.memory = 12696
# can_sample_self.memory = 12696
# nan
# can_sample_self.memory = 12697
# can_sample_self.memory = 12697
# nan
# can_sample_self.memory = 12698
# can_sample_self.memory = 12698
# nan
# can_sample_self.memory = 12699
# can_sample_self.memory = 12699
# nan
# can_sample_self.memory = 12700
# can_sample_self.memory = 12700
# nan
# can_sample_self.memory = 12701
# can_sample_self.memory = 12701
# nan
# can_sample_self.memory = 12702
# can_sample_self.memory = 12702
# nan
# can_sample_self.memory = 12703
# can_sample_self.memory = 12703
# nan
# can_sample_self.memory = 12704
# can_sample_self.memory = 12704
# nan
# can_sample_self.memory = 12705
# can_sample_self.memory = 12705
# nan
# can_sample_self.memory = 12706
# can_sample_self.memory = 12706
# nan
# can_sample_self.memory = 12707
# can_sample_self.memory = 12707
# nan
# can_sample_self.memory = 12708
# can_sample_self.memory = 12708
# nan
# can_sample_self.memory = 12709
# can_sample_self.memory = 12709
# nan
# can_sample_self.memory = 12710
# can_sample_self.memory = 12710
# nan
# can_sample_self.memory = 12711
# can_sample_self.memory = 12711
# nan
# can_sample_self.memory = 12712
# can_sample_self.memory = 12712
# nan
# can_sample_self.memory = 12713
# can_sample_self.memory = 12713
# nan
# can_sample_self.memory = 12714
# can_sample_self.memory = 12714
# nan
# can_sample_self.memory = 12715
# can_sample_self.memory = 12715
# nan
# can_sample_self.memory = 12716
# can_sample_self.memory = 12716
# nan
# can_sample_self.memory = 12717
# can_sample_self.memory = 12717
# nan
# can_sample_self.memory = 12718
# can_sample_self.memory = 12718
# nan
# can_sample_self.memory = 12719
# can_sample_self.memory = 12719
# nan
# can_sample_self.memory = 12720
# can_sample_self.memory = 12720
# nan
# can_sample_self.memory = 12721
# can_sample_self.memory = 12721
# nan
# can_sample_self.memory = 12722
# can_sample_self.memory = 12722
# nan
# can_sample_self.memory = 12723
# can_sample_self.memory = 12723
# nan
# can_sample_self.memory = 12724
# can_sample_self.memory = 12724
# nan
# can_sample_self.memory = 12725
# can_sample_self.memory = 12725
# nan
# can_sample_self.memory = 12726
# can_sample_self.memory = 12726
# nan
# can_sample_self.memory = 12727
# can_sample_self.memory = 12727
# nan
# can_sample_self.memory = 12728
# can_sample_self.memory = 12728
# nan
# can_sample_self.memory = 12729
# can_sample_self.memory = 12729
# nan
# can_sample_self.memory = 12730
# can_sample_self.memory = 12730
# nan
# can_sample_self.memory = 12731
# can_sample_self.memory = 12731
# nan
# can_sample_self.memory = 12732
# can_sample_self.memory = 12732
# nan
# can_sample_self.memory = 12733
# can_sample_self.memory = 12733
# nan
# can_sample_self.memory = 12734
# can_sample_self.memory = 12734
# nan
# can_sample_self.memory = 12735
# can_sample_self.memory = 12735
# nan
# can_sample_self.memory = 12736
# can_sample_self.memory = 12736
# nan
# can_sample_self.memory = 12737
# can_sample_self.memory = 12737
# nan
# can_sample_self.memory = 12738
# can_sample_self.memory = 12738
# nan
# can_sample_self.memory = 12739
# can_sample_self.memory = 12739
# nan
# can_sample_self.memory = 12740
# can_sample_self.memory = 12740
# nan
# can_sample_self.memory = 12741
# can_sample_self.memory = 12741
# nan
# can_sample_self.memory = 12742
# can_sample_self.memory = 12742
# nan
# can_sample_self.memory = 12743
# can_sample_self.memory = 12743
# nan
# can_sample_self.memory = 12744
# can_sample_self.memory = 12744
# nan
# can_sample_self.memory = 12745
# can_sample_self.memory = 12745
# nan
# can_sample_self.memory = 12746
# can_sample_self.memory = 12746
# nan
# can_sample_self.memory = 12747
# can_sample_self.memory = 12747
# 100%|███████████████████████████████████████████████████████████████████████████████▌| 199/200 [08:10<00:02,  2.48s/it]
# nan
# can_sample_self.memory = 12748
# can_sample_self.memory = 12748
# nan
# can_sample_self.memory = 12749
# can_sample_self.memory = 12749
# nan
# can_sample_self.memory = 12750
# can_sample_self.memory = 12750
# nan
# <<< episode >>>
# type=<class 'numpy.ndarray'>
# can_sample_self.memory = 12751
# can_sample_self.memory = 12751
# nan
# can_sample_self.memory = 12752
# can_sample_self.memory = 12752
# nan
# can_sample_self.memory = 12753
# can_sample_self.memory = 12753
# nan
# can_sample_self.memory = 12754
# can_sample_self.memory = 12754
# nan
# can_sample_self.memory = 12755
# can_sample_self.memory = 12755
# nan
# can_sample_self.memory = 12756
# can_sample_self.memory = 12756
# nan
# can_sample_self.memory = 12757
# can_sample_self.memory = 12757
# nan
# can_sample_self.memory = 12758
# can_sample_self.memory = 12758
# nan
# can_sample_self.memory = 12759
# can_sample_self.memory = 12759
# nan
# can_sample_self.memory = 12760
# can_sample_self.memory = 12760
# nan
# can_sample_self.memory = 12761
# can_sample_self.memory = 12761
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [08:11<00:00,  2.46s/it]
# nan
# can_sample_self.memory = 12762
# can_sample_self.memory = 12762
# nan
# can_sample_self.memory = 12763
# can_sample_self.memory = 12763
# nan

# %%
print(stats)
# Out:
# {'MSE Loss': [2375844.75, 5088436.5, 148934096.0, 6128829.0, 66793812.0, 86714056.0, 34752756.0, 122371416.0, 17602574.0, 45964020.0, 40935384.0, 30054684.0, 16265722.0, 4496816.5, 698920.75, 5575220.0, 43543744.0, 36385980.0, 14978548.0, 3181392.25, 7803361.5, 11161882.0, 11837208.0, 10103793.0, 7649597.5, 3984485.0, 2891495.75, 3287455.75, 4108750.5, 1361164.75, 572897.9375, 276383.90625, 342138.84375, 89853.2578125, 178701.875, 5055975.0, 6063861.0, 5776304.5, 3720219.25, 2239389.75, 1595274.125, 1590436.25, 34762232.0, 35345768.0, 30570076.0, 24857896.0, 16299360.0, 9290569.0, 10029487.0, 2752579.0, 3405988.25, 7997517.5, 12808483.0, 13855658.0, 11858585.0, 10494506.0, 5999563.0, 3672106.25, 672283.375, 1696216.0, 3149018.0, 2996269.25, 2642430.5, 2002696.625, 1489426.75, 1692573.375, 1415853.0, 17030168.0, 16680293.0, 14665839.0, 9290231.0, 7906792.0, 8511752.0, 9984770.0, 9117038.0, 8242476.5, 1481299.125, 950045.625, 608150.6875, 1207343.375, 1096141.125, 1478952.875, 1262674.125, 885632.875, 705347.25, 747080.875, 889540.125, 330548.34375, 774374.4375, 399514.21875, 1821773.375, 7760613.5, 7333156.0, 4572944.5, 1343483.0, 847639.625, 344435.34375, 3406248.0, 2502547.5, 1663992.0, 2815399.75, 2420053.0, 2180819.25, 1967432.75, 1762336.0, 1067328.0, 1064056.0, 462109.3125, 196022.5, 383738.9375, 457978.3125, 1109020.125, 415541.71875, 534441.875, 1343662.375, 817177.1875, 749736.125, 871885.875, 1547868.125, 1129164.0, 1167713.75, 557505.6875, 473510.625, 500708.90625, 309938.125, 246064.828125, 243152.578125, 168651.0, 201275.640625, 6063694.5, 153179.609375, 414177.96875, 222285.75, 197771.390625, 405284.875, 6920341.5, 7136596.5, 5821883.5, 5307263.5, 170440.765625, 3507538.75, 2443632.75, 2309814.5, 1887583.75, 1677413.875, 1530407.5, 2151472.25, 1060381.75, 692530.8125, 521325.65625, 1179946.875, 508391.0625, 977666.75, 10012518.0, 527368.75, 790972.8125, 1151889.0, 1987512.125, 13125493.0, 12633084.0, 11453396.0, 8819443.0, 9020220.0, 7604081.0, 5866318.0, 2318208.0, 4894665.0, 1304441.125, 3483202.5, 4199247.0, 5578382.0, 5550746.5, 5430184.5, 4429474.0, 2066770.25, 2598411.0, 2541288.5, 2755339.0, 3472962.5, 2510293.75, 2181429.5, 2221858.25, 1872099.5, 1278077.0, 4337212.0, 6230499.5, 680851.75, 631272.9375, 572406.1875, 555600.0, 43532.2265625, 309974.125, 99003.328125, 333341.09375, 158054.828125, 277210.9375, 123358.2109375, 135424.84375, 74844.203125, 192741.90625, 286544.53125, 381786.03125, 78600.3828125, 98985.375, 36879.625, 193286.8125, 122929.8828125, 281521.46875, 394851.90625, 2058008.125, 3667546.0, 3651612.25, 3828765.25, 2010555.75, 3397436.5, 1449582.75, 948357.4375, 505434.8125, 519916.40625, 112253.34375, 275099.59375, 152840.59375, 264579.1875, 203376.15625, 770138.375, 310961.3125, 488152.34375, 518785.34375, 18288.572265625, 252882.625, 262369.21875, 301675.34375, 153204.296875, 186489.890625, 111265.25, 5757175.0, 43352.58203125, 360575.4375, 370161.46875, 314837.0625, 291766.46875, 167080.59375, 1612900.25, 1433642.5, 1011233.875, 331627.75, 1126271.5, 924737.1875, 1458115.375, 1250145.25, 647482.8125, 354149.15625, 4273553.0, 4431808.5, 4098698.5, 2790360.5, 954550.0, 1817647.625, 1603105.25, 2205655.25, 12442600.0, 1036433.125, 884409.375, 1201549.875, 1931578.125, 2690033.25, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, ...

# %% [markdown]
# # Here Lies the Problem
# As you see in above output we are getting nan in the loss which is because we are getting nan in the actions that the neural network is predicting. We are unable to pinpoint the issue it could be because of incorrect gradients, faulty loss function, bad policy or learning rate parameter, or faulty inputs (well inputs are faulty because the previous output is fault, but unable to understand why the first output is coming as nan even when input is correct)

# %% [markdown]
# ## Show results

# %% [markdown]
# ### Plot execution stats

# %%
plot_stats(stats)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# ### Plot the cost to go: $ - \max_a \hat q(s,a|\theta)$

# %%
#plot_cost_to_go(gym_env, q_network, xlabel='Car Position', ylabel='Velocity')

# %% [markdown]
# ### Show resulting policy: $\pi(s)$

# %%
#plot_max_q(gym_env, q_network, xlabel='Car Position', ylabel='Velocity', action_labels=['Back', 'Do nothing', 'Forward'])

# %% [markdown]
# ### Test the resulting agent

# %%
def test_agent(env: gym.Env, policy: Callable, episodes: int = 10) -> None:
    print('<< test_agent >> ')
    #plt.figure(figsize=(8, 8))
    for episode in range(episodes):
        state = env.reset()
        done = False
        #img = plt.imshow(env.render(mode='rgb_array'))
        while not done:
            p = policy(state)
            if isinstance(p, np.ndarray):
                action = np.random.choice(4, p=p)
            else:
                action = p
            next_state, _, done, _ = env.step(action)
            #img.set_data(env.render(mode='rgb_array'))
            #plt.axis('off')
            #display.display(plt.gcf())
            #display.clear_output(wait=True)
            state = next_state

# %%
#test_agent(gym_env, q_network, episodes=2)
